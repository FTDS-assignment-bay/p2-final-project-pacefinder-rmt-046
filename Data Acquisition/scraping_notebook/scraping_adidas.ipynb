# %% [markdown]
# ---
#
# Notebook ini digunakan untuk proses scraping data pada website Amazon
#
# Proses scraping menggunakan bantuan ScraperAPI untuk melakukan scraping website dan Beautiful Soup untuk parsing data
#
# ---

# %% [markdown]
# # Import Library

# %% [markdown]
# Import Library yang dibutuhkan

# %%
import pandas as pd
import json
import time
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# # API

# %%
api_key = "d62541de90843bd5ad38c1bc99e40639"

# %% [markdown]
# # URL

# %%
def nike_url(page=1):
    url = f"https://www.amazon.com/s?k=nike+running+shoes&page={page}&xpid=c19ZYZKsdabEP&crid=3UJSBHJW2MC0G&qid=1759744785&sprefix=nike+running+shoe%2Caps%2C304&ref=sr_pg_{page}"
    return url

def adidas_url(page=1):
    url = f"https://www.amazon.com/s?k=adidas+running+shoes&page={page}&xpid=WdPRXIQzs_yZr&crid=24Y534EW495K2&qid=1759753219&sprefix=adida+running+shoes%2Caps%2C306&ref=sr_pg_{page}"
    return url

def nb_url(page=1):
    url = f"https://www.amazon.com/s?k=new+balance+running+shoes&page={page}&xpid=cJV8-hCtiPB2m&crid=316I8Y3T8QK73&qid=1759753290&sprefix=new+balancerunning+shoes%2Caps%2C347&ref=sr_pg_{page}"
    return url

def puma_url(page=1):
    url = f"https://www.amazon.com/s?k=puma+running+shoes&page={page}&xpid=h1o6i4Me3b_CG&crid=7MXYXUX5LFHZ&qid=1759820901&sprefix=pumrunning+shoes%2Caps%2C297&ref=sr_pg_3{page}"
    return url

def reebok_url(page=1):
    url = f"https://www.amazon.com/s?k=reebok+running+shoes&page={page}&xpid=oTc7T-rOWodFB&crid=2PW6C859EW6TL&qid=1759758846&sprefix=reebokrunning+shoes%2Caps%2C354&ref=sr_pg_{page}"
    return url

# %% [markdown]
# # adidas

# %%
response=[]

for page in range(1,6):
    """
    Perulangan untuk melakukan scraping sebanyak 5 halaman
    """
    url = adidas_url(page=page)

    # Token API
    payload = {
    'api_key': api_key,
    'url': url,
    'country_code': 'us',  
    'render': 'false'      
    }

    # Error Handling agar tidak berhenti saat tidak ada respon
    try:
        res = requests.get("https://api.scraperapi.com", params=payload, timeout=15)
        res.raise_for_status()  
        response.append(res)
        print(f"Sukses mengambil halaman {page}")
    except requests.exceptions.RequestException as e:
        print(f"Gagal mengambil halaman {page}: {e}")
        continue  
    
    # Time delay
    time.sleep(5)  


# Ekstrak link produk
product_url = []
base_seen = set()  # track unique product bases

for res in response:
    """
    Perulangan untuk membuka data hasil scraping
    """
    extractor = BeautifulSoup(res.text, 'html.parser')

    # Ambil semua elemen hyperlink
    links = extractor.find_all('a', href=True)
    for link in links:
        href = link['href']

        if (
            "/dp/" in href 
            and not href.startswith("/gp/") 
            and "aax-us-iad" not in href 
            and "slredirect" not in href
            and "dp/product" not in href 
        ):
            # Check that the URL belongs to the Adidas brand
            if "adidas" not in href.lower():
                continue  # skip non-Adidas links
            
            # Membuat link URL
            base_url = "https://www.amazon.com"
            product_link = href.split('?')[0]  
            full_url = base_url + product_link

            # dedupe by product family (everything before /dp/)
            base_product = full_url.split("/dp/")[0]

            # Hindari duplikat
            if base_product not in base_seen:
                base_seen.add(base_product)
                product_url.append(full_url)

# Menampilkan hasil link produk
for i, url in enumerate(product_url, start=1):
    print(f"{i}. {url}")


scraping_review = []
print(f"url number: {len(product_url)}")
for i,page in enumerate(product_url):
    """
    Perulangan untuk melakukan scraping terhadap semua link yang ada di list url
    """
    # Token API
    payload = {
    'api_key': api_key,
    'url': page,
    'country_code': 'us',  
    'render': 'true'      
    }

    # Error Handling agar tidak berhenti saat tidak ada respon
    try:
        response = requests.get("https://api.scraperapi.com", params=payload, timeout=15)
        response.raise_for_status()  
        scraping_review.append(response)
        print(f"url ke-{i+1} Sukses: {page}")
    except requests.exceptions.RequestException as e:
        print(f"url ke-{i+1} Gagal: {page}: {e}")
        continue  
    
    # Time Delay
    time.sleep(5)  



# List untuk menyimpan data produk
review_data =[]

for product in scraping_review:
    """
    Perulangan untuk melakukan parsing data hasil scraping
    """
    # Memanggil model BS4
    parser = BeautifulSoup(product.text, 'html.parser')

    # Parsing Nama Produk
    title = parser.find(id='productTitle')
    product_title=title.get_text(strip=True) if title else 'N/A'

    # Parsing Gambar produk
    img_tag = parser.select_one('#imgTagWrapperId img')
    image_url = img_tag['src'] if img_tag else 'N/A'

    # Parsing Harga
    # Try all possible price containers
    price = (
        parser.select_one('.a-price-whole') or
        parser.select_one('.a-offscreen') or
        parser.select_one('.olpWrapper.a-size-small')
    )
    # Extract text safely
    product_price = price.get_text(strip=True) if price else 'N/A'

    # Parsing Rating Produk
    rating = parser.find('span', {'class': 'a-icon-alt'})
    product_rating=rating.get_text(strip=True) if rating else 'N/A'

    # Parsing Customers say
    p_tag = parser.find("p", class_="a-spacing-small")
    customer_say = p_tag.get_text(strip=True) if p_tag else None
    
    # Mengambil data reviews
    reviews = []
    review_blocks = parser.find_all('li', {'data-hook': 'review'})
    for block in review_blocks:

        # Mengambil data rating reviews
        rating_tag = block.find('i', {'data-hook': 'review-star-rating'})
        rating_val = 'N/A'
        if rating_tag:
            rating_span = rating_tag.find('span', class_='a-icon-alt')
            rating_val = rating_span.get_text(strip=True) if rating_span else 'N/A'

        # Mengambil teks reviews
        text_tag = block.find('span', {'data-hook': 'review-body'})
        text_val = 'N/A'
        if text_tag:
            inner_span = text_tag.find('span')
            text_val = inner_span.get_text(strip=True) if inner_span else text_tag.get_text(strip=True)

        # Menyimpan data reviews jika teks dan rating not null
        if text_val != 'N/A' and rating_val != 'N/A':
            reviews.append({
                'review': text_val,
                'rating': rating_val
            })

    # Skip produk tanpa review
    if not reviews:
        continue  

    # Membuat Dictionary review
    dict_review = {
        "title" : product_title,
        "rating" : product_rating,
        "price" : product_price,
        "img_url": image_url,
        "Brand": "Adidas",
        "Customer_say": customer_say,
        "Review": reviews
    }

    # Menyimpan data review produk ke dalam list
    review_data.append(dict_review)



# Menghapus data tanpa title
review_data = [item for item in review_data if item["title"] != "N/A"]
review_data


# Menyimpan data dalam format JSON
with open("adidas.json", "w", encoding="utf-8") as review_json:
    json.dump(review_data, review_json, indent=2, ensure_ascii=True)
# Out:
# Sukses mengambil halaman 1
# Sukses mengambil halaman 2
# Sukses mengambil halaman 3
# Sukses mengambil halaman 4
# Sukses mengambil halaman 5
# 1. https://www.amazon.com/adidas-Racer-Adapt-Sneaker-Black/dp/B0CKM9F15Z/ref=sr_1_1
# 2. https://www.amazon.com/adidas-Falcon-Sneaker-Black-White/dp/B0CKMM7KSN/ref=sr_1_2
# 3. https://www.amazon.com/adidas-Mens-Swift-Sneaker-Black/dp/B0BHPV45TW/ref=sr_1_3
# 4. https://www.amazon.com/adidas-Mens-Ultraboost-Running-White/dp/B09VCNN65T/ref=sr_1_4
# 5. https://www.amazon.com/adidas-Womens-Falcon-Sneaker-Black/dp/B0CKMKV6H8/ref=sr_1_5
# 6. https://www.amazon.com/adidas-Mens-Kaptir-Sneaker-Black/dp/B0BG94ZLMP/ref=sr_1_6
# 7. https://www.amazon.com/adidas-Ultradream-Sportswear-Sneaker-Black/dp/B0D22WK79T/ref=sr_1_7
# 8. https://www.amazon.com/adidas-Duramo-Running-Sneaker-Silver/dp/B0D2JDHKDF/ref=sr_1_8
# 9. https://www.amazon.com/adidas-Questar-Sneaker-Preloved-Silver/dp/B0CKM8J4WX/ref=sr_1_9
# 10. https://www.amazon.com/adidas-Racer-Footwear-White-Silver/dp/B0C6XPC39Q/ref=sr_1_10
# 11. https://www.amazon.com/adidas-Womens-Duramo-Running-Sneaker/dp/B0D2JBV2ZC/ref=sr_1_11
# 12. https://www.amazon.com/adidas-JH7253_580-Ultraboost-5X-Shoes/dp/B0DQ6D8XQM/ref=sr_1_12
# 13. https://www.amazon.com/adidas-Mens-Racer-Running-Black/dp/B091MPYGKC/ref=sr_1_14
# 14. https://www.amazon.com/adidas-Mens-Falcon-White-Black/dp/B09Y7VQ32X/ref=sr_1_15
# 15. https://www.amazon.com/adidas-Kaptir-Sneaker-White-Black/dp/B0DJV8Q28D/ref=sr_1_16
# 16. https://www.amazon.com/adidas-Mens-X_PLR-Sneaker-Black/dp/B0CKMQBKW4/ref=sr_1_18
# 17. https://www.amazon.com/adidas-Lightstride-Sportswear-Sneaker-Scarlet/dp/B0D2JBP6JV/ref=sr_1_19
# 18. https://www.amazon.com/adidas-Supernova-Rise-Running-Shoes/dp/B0D8WSS4BX/ref=sr_1_20
# 19. https://www.amazon.com/adidas-Response-Sneaker-Crystal-Metallic/dp/B0BXQ6DSK4/ref=sr_1_21
# 20. https://www.amazon.com/adidas-Womens-X_PLR-Sneaker-White/dp/B0CPS64W3Y/ref=sr_1_22
# 21. https://www.amazon.com/adidas-Mens-Sneaker-Dark-White/dp/B0CKMMB3QV/ref=sr_1_23
# 22. https://www.amazon.com/adidas-Sneaker-Black-White-Carbon/dp/B0CKMMR746/ref=sr_1_24
# 23. https://www.amazon.com/adidas-Lightshift-Sportswear-Sneaker-Black/dp/B0D22TQZ6Q/ref=sr_1_25
# 24. https://www.amazon.com/adidas-Womens-Sneaker-Purple-Scarlet/dp/B0DHZT6GT2/ref=sr_1_26
# 25. https://www.amazon.com/adidas-Womens-Sneaker-Silver-Metallic/dp/B0BHPST3LP/ref=sr_1_27
# 26. https://www.amazon.com/adidas-Supernova-Running-Sneaker-White/dp/B0D2JF9S78/ref=sr_1_28
# 27. https://www.amazon.com/adidas-Duramo-Running-Sneaker-White/dp/B0DHXGXJ7H/ref=sr_1_29
# 28. https://www.amazon.com/adidas-Terrex-Tracefinder-Running-Sneaker/dp/B0D2JCZTS5/ref=sr_1_30
# 29. https://www.amazon.com/adidas-Kaptir-FTWWHT-CBLACK-Metallic/dp/B0CPSBYG79/ref=sr_1_31
# 30. https://www.amazon.com/adidas-Mens-Eclyptix-Sneaker-White/dp/B0D22WBCWP/ref=sr_1_32
# 31. https://www.amazon.com/adidas-Duramo-Sneaker-Black-Carbon/dp/B0BG6CPHZ8/ref=sr_1_33
# 32. https://www.amazon.com/adidas-Ultrabounce-Running-Sneaker-Black/dp/B0D2JGX4RF/ref=sr_1_34
# 33. https://www.amazon.com/adidas-Womens-Running-Sneaker-Metallic/dp/B0D33R68XR/ref=sr_1_35
# 34. https://www.amazon.com/adidas-Womens-Puremotion-Sportswear-Sneaker/dp/B0BHPSG7XM/ref=sr_1_37
# 35. https://www.amazon.com/Adidas-Supernova-Prima-Running-Shoes/dp/B0DKVM27FK/ref=sr_1_38
# 36. https://www.amazon.com/adidas-Astrastar-Sneaker-Black-White/dp/B0DJV5WQVR/ref=sr_1_39
# 37. https://www.amazon.com/adidas-Duramo-Sneaker-Metallic-Aurora/dp/B0BXQ661QF/ref=sr_1_40
# 38. https://www.amazon.com/adidas-Unisex-Ultraboost-Running-Crystal/dp/B09VCLVMFH/ref=sr_1_41
# 39. https://www.amazon.com/adidas-Falcon-Running-Sneaker-Metallic/dp/B0D32XWJ4K/ref=sr_1_42
# 40. https://www.amazon.com/adidas-Ultrabounce-Sneaker-White-Silver/dp/B0CKMBSBG3/ref=sr_1_43
# 41. https://www.amazon.com/adidas-Womens-Vario-Black-White/dp/B08CZDDWX9/ref=sr_1_44
# 42. https://www.amazon.com/adidas-Womens-Swift-Sneaker-Preloved/dp/B0DJV7K2JJ/ref=sr_1_45
# 43. https://www.amazon.com/adidas-Originals-Womens-Swift-Sneaker/dp/B091V6SM5Z/ref=sr_1_47
# 44. https://www.amazon.com/adidas-Womens-Sneaker-Blanch-Wonder/dp/B0DLTD1GBV/ref=sr_1_48
# 45. https://www.amazon.com/Under-Armour-Charged-Assert-Running/dp/B09XBVM335/ref=sr_1_49
# 46. https://www.amazon.com/adidas-Ultraboost-Running-Black-White/dp/B091MQ45J3/ref=sr_1_50
# 47. https://www.amazon.com/adidas-X_PLR-Sneaker-Black-White/dp/B0DJV5N49V/ref=sr_1_51
# 48. https://www.amazon.com/adidas-Womens-Pureboost-Sneaker-Metallic/dp/B0CKMC9SLT/ref=sr_1_54
# 49. https://www.amazon.com/adidas-Womens-Supernova-Stride-Sneaker/dp/B0BXQ4RWYD/ref=sr_1_55
# 50. https://www.amazon.com/adidas-Womens-Ultradream-Sportswear-Sneaker/dp/B0D2JG29RH/ref=sr_1_56
# 51. https://www.amazon.com/adidas-Womens-Cloudfoam-Sportswear-Sneakers/dp/B0BZ5NB719/ref=sr_1_58
# 52. https://www.amazon.com/adidas-Mens-Racer-Sneaker-White/dp/B0BHPTW5WL/ref=sr_1_59
# 53. https://www.amazon.com/adidas-Pureboost-Sneaker-Silver-Metallic/dp/B0CKM95RJC/ref=sr_1_60
# 54. https://www.amazon.com/adidas-Womens-SoulStride-Sneaker-Crystal/dp/B0BG3D2XZM/ref=sr_1_61
# 55. https://www.amazon.com/adidas-Supernova-Running-Sneaker-Metallic/dp/B0D2Z2HBK2/ref=sr_1_62
# 56. https://www.amazon.com/adidas-FTWWHT-PURTEA-Adizero-whitePure/dp/B0DVQ2ZSBJ/ref=sr_1_63
# 57. https://www.amazon.com/adidas-Womens-Ultraboost-Sneaker-White/dp/B0CPS85BCS/ref=sr_1_64
# 58. https://www.amazon.com/adidas-Falcon-Sneaker-Silver-Metallic/dp/B0CKMCS5CJ/ref=sr_1_65
# 59. https://www.amazon.com/adidas-Adizero-Boston-Sneaker-Metallic/dp/B0CSM3JRQH/ref=sr_1_66
# 60. https://www.amazon.com/adidas-Ultraboost-Light-Running-Shoes/dp/B0BRNQWSM9/ref=sr_1_67
# 61. https://www.amazon.com/adidas-Mens-Sneaker-Grey-Shadow/dp/B0BHPQX6TQ/ref=sr_1_69
# 62. https://www.amazon.com/adidas-Supernova-Running-Sneaker-Bright/dp/B0D33RT5X2/ref=sr_1_70
# 63. https://www.amazon.com/adidas-Response-Super-Sneaker-Silver/dp/B0C2JVDRHQ/ref=sr_1_71
# 64. https://www.amazon.com/adidas-Kaptir-Womens-Running-Shoes/dp/B0CPSBPBN3/ref=sr_1_72
# 65. https://www.amazon.com/adidas-Womens-Response-Sneaker-Purple/dp/B0CM84CJKZ/ref=sr_1_73
# 66. https://www.amazon.com/adidas-Womens-X_PLRPHASE-Sneaker-Preloved/dp/B0CMRXSFNX/ref=sr_1_74
# 67. https://www.amazon.com/adidas-Sneaker-Yellow-Black-White/dp/B0DHZVLKJ2/ref=sr_1_76
# 68. https://www.amazon.com/adidas-Ultraboost-Running-Sneaker-White/dp/B0D3P22L2W/ref=sr_1_77
# 69. https://www.amazon.com/adidas-Womens-RunBlaze-Sneaker-Bliss/dp/B0DLBSZK38/ref=sr_1_78
# 70. https://www.amazon.com/adidas-Terrex-Anylander-Sneaker-Strata/dp/B0CKM7S36V/ref=sr_1_79
# 71. https://www.amazon.com/adidas-Ultraboost-Sneaker-White-Glory/dp/B0CKM6KYWJ/ref=sr_1_80
# 72. https://www.amazon.com/adidas-Sneaker-Purple-Better-Scarlet/dp/B0DJV6W2P6/ref=sr_1_81
# 73. https://www.amazon.com/adidas-Flowboost-Sportswear-Sneaker-Collegiate/dp/B0D2JDF3BR/ref=sr_1_83
# 74. https://www.amazon.com/adidas-Running-Sneaker-Wonder-Alumina/dp/B0D2JF99JK/ref=sr_1_85
# 75. https://www.amazon.com/adidas-Originals-Swift-Sneaker-Black/dp/B098999VT2/ref=sr_1_86
# 76. https://www.amazon.com/adidas-Swift-Womens-F35206-Size/dp/B07TXRCKRD/ref=sr_1_87
# 77. https://www.amazon.com/adidas-Sportswear-Sneaker-Court-Carbon/dp/B0D2JDMTT3/ref=sr_1_88
# 78. https://www.amazon.com/adidas-Lightstride-Sportswear-Sneaker-Crystal/dp/B0D2JCVGJB/ref=sr_1_90
# 79. https://www.amazon.com/adidas-Adistar-Sneaker-White-Black/dp/B0CM81J2BD/ref=sr_1_91
# 80. https://www.amazon.com/adidas-X_PLR-Sneaker-White-Unisex/dp/B0CRDF7YPV/ref=sr_1_92
# 81. https://www.amazon.com/adidas-Barreda-Decode-Sneaker-Impact/dp/B0DJV4N6HX/ref=sr_1_93
# 82. https://www.amazon.com/adidas-Swift-Sneaker-Black-White/dp/B0BHPSFLNT/ref=sr_1_94
# 83. https://www.amazon.com/adidas-Ultraboost-Running-Legacy-Indigo/dp/B091M9K65B/ref=sr_1_95
# 84. https://www.amazon.com/adidas-Terrex-Agravic-Running-Sneaker/dp/B0D2PHFZYZ/ref=sr_1_96
# 85. https://www.amazon.com/Adidas-JH7248-Ultraboost-5X-Shoes/dp/B0DKVBFCYF/ref=sr_1_98
# 86. https://www.amazon.com/adidas-Supernova-Stride-Sneaker-Metallic/dp/B0CM7Q2GG8/ref=sr_1_100
# 87. https://www.amazon.com/adidas-Womens-Questar-Sneaker-Silver/dp/B0CKM9J7P2/ref=sr_1_101
# 88. https://www.amazon.com/adidas-Samba-Classic-Shoes-Mens/dp/B000CER6SS/ref=sr_1_102
# 89. https://www.amazon.com/adidas-Womens-Breaknet-Sneaker-Alumina/dp/B0DJV9NNZY/ref=sr_1_103
# 90. https://www.amazon.com/adidas-Womens-Response-Running-Sneaker/dp/B0D2JGX8GR/ref=sr_1_104
# 91. https://www.amazon.com/adidas-Womens-Sportswear-Sneaker-Alumina/dp/B0D2JF8D2N/ref=sr_1_106
# 92. https://www.amazon.com/adidas-Terrex-Soulstride-Sneaker-Crystal/dp/B0C2JY7TK9/ref=sr_1_107
# 93. https://www.amazon.com/adidas-Falcon-Sneaker-Black-Unisex/dp/B0CKMCK1VH/ref=sr_1_108
# 94. https://www.amazon.com/adidas-UBounce-Sneaker-White-Black/dp/B0CCQ1MBPN/ref=sr_1_109
# 95. https://www.amazon.com/adidas-Womens-Ultraboost-Running-Crystal/dp/B09VCKXRWG/ref=sr_1_110
# 96. https://www.amazon.com/adidas-Duramo-Sneaker-Carbon-Unisex/dp/B0BHPWG6XD/ref=sr_1_114
# 97. https://www.amazon.com/adidas-Pureboost-Running-Solar-Yellow/dp/B09KMJ3MNJ/ref=sr_1_116
# 98. https://www.amazon.com/adidas-Barreda-Sneaker-Earth-Strata/dp/B0DLBRVVPB/ref=sr_1_118
# 99. https://www.amazon.com/ALEADER-Energycloud-Walking-Running-Treadmill/dp/B09PNFMMXP/ref=sr_1_119
# 100. https://www.amazon.com/adidas-Womens-Ultraboost-Running-Collegiate/dp/B091MCKN74/ref=sr_1_120
# 101. https://www.amazon.com/adidas-X_PLRPATH-Sneaker-Black-Cross/dp/B0BZ5TNVKF/ref=sr_1_122
# 102. https://www.amazon.com/Under-Armour-Charged-Assert-Black/dp/B087TH4JM6/ref=sr_1_123
# 103. https://www.amazon.com/adidas-Lightstride-Sneaker-Collegiate-Silver/dp/B0D22YD984/ref=sr_1_124
# 104. https://www.amazon.com/adidas-Womens-Running-White-Purple/dp/B08N5FPSWV/ref=sr_1_125
# 105. https://www.amazon.com/adidas-Womens-Running-Carbon-Metallic/dp/B08MY72SKK/ref=sr_1_127
# 106. https://www.amazon.com/adidas-Mens-Running-Black-White/dp/B09DZW747P/ref=sr_1_128
# 107. https://www.amazon.com/adidas-womens-Racer-Grey-White/dp/B087KVQYXJ/ref=sr_1_129
# 108. https://www.amazon.com/adidas-Falcon-Black-Unisex-Little/dp/B09VCT6HX2/ref=sr_1_130
# 109. https://www.amazon.com/adidas-Womens-Ultrabounce-Sneaker-Black/dp/B0CKMK6Y1N/ref=sr_1_131
# 110. https://www.amazon.com/adidas-Sneaker-Strata-Silver-Pebble/dp/B0CM7VT9KN/ref=sr_1_132
# 111. https://www.amazon.com/adidas-Response-Running-Sneaker-Carbon/dp/B0D2JGJ799/ref=sr_1_133
# 112. https://www.amazon.com/adidas-Womens-Tracefinder-Running-Sneaker/dp/B0D2JKD1T3/ref=sr_1_134
# 113. https://www.amazon.com/adidas-Supernova-Running-Sneaker-Crystal/dp/B0D2Z7XP7Q/ref=sr_1_135
# 114. https://www.amazon.com/adidas-White-Tint-Silver-Metallic/dp/B0BJW3LTGJ/ref=sr_1_136
# 115. https://www.amazon.com/adidas-Womens-Ultrarun-Running-Sneaker/dp/B0D2JBCQ3G/ref=sr_1_137
# 116. https://www.amazon.com/adidas-X_PLRBOOST-Running-Black-White/dp/B0B5YNNWSK/ref=sr_1_138
# 117. https://www.amazon.com/adidas-Unisex-Ultraboost-Sneaker-White/dp/B0CM847GBR/ref=sr_1_139
# 118. https://www.amazon.com/adidas-Mens-2000-Runner-Sneaker/dp/B0CKMHY6Y6/ref=sr_1_140
# 119. https://www.amazon.com/adidas-Terrex-Soulstride-Crystal-Wonder/dp/B0CC22QCCG/ref=sr_1_141
# 120. https://www.amazon.com/adidas-Tracefinder-Climaproof-Running-Preloved/dp/B0DHW1F1J7/ref=sr_1_142
# 121. https://www.amazon.com/adidas-Adizero-Mens-Running-Shoes/dp/B0CKM1KCWZ/ref=sr_1_143
# 122. https://www.amazon.com/adidas-Unisex-Pureboost-Running-Shadow/dp/B09KP61496/ref=sr_1_144
# 123. https://www.amazon.com/adidas-Ultrarun-Running-Sneaker-Preloved/dp/B0D2JJH6N4/ref=sr_1_145
# 124. https://www.amazon.com/adidas-Astrastar-Sneaker-Alumina-Metallic/dp/B0DJV35KT4/ref=sr_1_146
# 125. https://www.amazon.com/adidas-Fortarun-Sportswear-Sneaker-Unisex/dp/B0D2JJL6QB/ref=sr_1_148
# 126. https://www.amazon.com/adidas-Supernova-Running-Sneaker-Unisex/dp/B0D2JJW79Q/ref=sr_1_149
# 127. https://www.amazon.com/adidas-Response-Shoes-Mens-White/dp/B0CB9F5NZV/ref=sr_1_150
# 128. https://www.amazon.com/adidas-Mens-Runfalcon-Black-White/dp/B087M2KPR2/ref=sr_1_151
# 129. https://www.amazon.com/adidas-Kaptir-Sneaker-Blanch-Alumina/dp/B0CKMMN1BT/ref=sr_1_153
# 130. https://www.amazon.com/adidas-Duramo-Trail-Running-Royal/dp/B08N5JDB2V/ref=sr_1_154
# 131. https://www.amazon.com/adidas-Alphaboost-Sneaker-White-Solid/dp/B0CKMC3TYC/ref=sr_1_155
# 132. https://www.amazon.com/adidas-Elastic-Sportswear-Sneaker-Unisex/dp/B0D22W71HC/ref=sr_1_156
# 133. https://www.amazon.com/adidas-Duramo-Running-Sneakers-Shoes/dp/B0D31V48XG/ref=sr_1_157
# 134. https://www.amazon.com/adidas-AlphaBoost-Running-Black-Magic/dp/B09VCL828H/ref=sr_1_158
# 135. https://www.amazon.com/adidas-Originals-Sneaker-Running-Medium/dp/B00139U3DQ/ref=sr_1_161
# 136. https://www.amazon.com/adidas-Falcon-Running-Sneaker-Black/dp/B0D2JF57GN/ref=sr_1_162
# 137. https://www.amazon.com/adidas-Unisex-Avery-Running-Carbon/dp/B09VCLWLZZ/ref=sr_1_163
# 138. https://www.amazon.com/adidas-Terrex-SoulStride-Sneaker-Carbon/dp/B0BHPTYQGP/ref=sr_1_164
# 139. https://www.amazon.com/adidas-Ultrabounce-Mens-Shoes-Color/dp/B0CC6J634K/ref=sr_1_165
# 140. https://www.amazon.com/adidas-Womens-Kantai-Sportswear-Sneaker/dp/B0D2JFF32Q/ref=sr_1_168
# 141. https://www.amazon.com/adidas-Amplimove-Training-Sneaker-Lucid/dp/B0D2JFPH31/ref=sr_1_170
# 142. https://www.amazon.com/adidas-Alphaboost-Sneaker-Collegiate-University/dp/B0DF12DR57/ref=sr_1_171
# 143. https://www.amazon.com/adidas-Unisex-Turnaround-Sneaker-Crystal/dp/B0CMGPZRC5/ref=sr_1_172
# 144. https://www.amazon.com/adidas-Lightblaze-Sneaker-Silver-Metallic/dp/B0DJTYKXNZ/ref=sr_1_173
# 145. https://www.amazon.com/adidas-Kantai-Sportswear-Sneaker-Charcoal/dp/B0D22WSCYZ/ref=sr_1_174
# 146. https://www.amazon.com/adidas-Duramo-Sneaker-Fusion-Unisex/dp/B0BHPV8H17/ref=sr_1_177
# 147. https://www.amazon.com/adidas-Ultradream-Sneaker-White-Unisex/dp/B0DNGJKXCY/ref=sr_1_178
# 148. https://www.amazon.com/adidas-Ultrabounce-Sneaker-Black-Unisex/dp/B0CKMC9C19/ref=sr_1_180
# 149. https://www.amazon.com/adidas-Runner-Sneaker-Blanch-Cargo/dp/B0CKMKNRXB/ref=sr_1_182
# 150. https://www.amazon.com/adidas-Ultrarun-Sneaker-Unisex-Little/dp/B0DLCFVZQZ/ref=sr_1_183
# 151. https://www.amazon.com/adidas-Womens-Lightshift-Sportswear-Sneaker/dp/B0D22W7Y3L/ref=sr_1_184
# 152. https://www.amazon.com/adidas-Sportswear-Sneaker-Wonder-Quartz/dp/B0D28TJSHP/ref=sr_1_185
# 153. https://www.amazon.com/adidas-Unisex-VULCRAID3R-Running-White/dp/B09KMJX6Z7/ref=sr_1_186
# 154. https://www.amazon.com/adidas-Mould-Bungee-Sneaker-Collegiate/dp/B0CKMK4ZRQ/ref=sr_1_187
# 155. https://www.amazon.com/adidas-Mens-Barreda-Decode-Sneaker/dp/B0DJTXZKKM/ref=sr_1_188
# 156. https://www.amazon.com/adidas-Falcon-Sneaker-Unisex-Little/dp/B0DLCN1ZHK/ref=sr_1_189
# 157. https://www.amazon.com/adidas-Womens-Ubounce-Alphaskin-Sneaker/dp/B0BZ5B116M/ref=sr_1_190
# 158. https://www.amazon.com/adidas-Elastic-Sneaker-Scarlet-Metallic/dp/B0DHZJT9Z3/ref=sr_1_191
# 159. https://www.amazon.com/adidas-Elastic-Sneaker-Better-Scarlet/dp/B0CRH8X6LT/ref=sr_1_192
# 160. https://www.amazon.com/adidas-Womens-Duramo-Sneaker-Carbon/dp/B0BG6B24Q8
# 161. https://www.amazon.com/adidas-Lightshift-Sportswear-Sneaker-Lavender/dp/B0D22QZ2DX
# 162. https://www.amazon.com/adidas-Supernova-Stride-Sneaker-Scarlet/dp/B0C2JTDRD4
# 163. https://www.amazon.com/adidas-Grand-Sportswear-Sneaker-Metallic/dp/B0D22WQPT3
# 164. https://www.amazon.com/adidas-Cloudfoam-Sportswear-Sneaker-Preloved/dp/B0D2JD494C
# 165. https://www.amazon.com/adidas-unisex-kids-Kaptir-3-0-Black/dp/B0BTZB64X2
# 166. https://www.amazon.com/adidas-Kaptir-Sneaker-Aurora-Metallic/dp/B0DJV7L7RF
# 167. https://www.amazon.com/adidas-Duramo-Elastic-Sneaker-Bright/dp/B0DJV9SQP9
# 168. https://www.amazon.com/adidas-Duramo-Elastic-Sportswear-Sneaker/dp/B0D22TBK34
# 169. https://www.amazon.com/adidas-Ultrarun-Elastic-Sneaker-Unisex/dp/B0DHZF2JW9
# 170. https://www.amazon.com/adidas-Womens-Supernova-Sneaker-Bright/dp/B0BHPT278K
# 171. https://www.amazon.com/adidas-Womens-Breaknet-Sneaker-Shadow/dp/B0CKMP3YLJ
# 172. https://www.amazon.com/adidas-Ultrabounce-Elastic-Sneaker-Unisex/dp/B0CKMBZHYY
# 173. https://www.amazon.com/adidas-Sneaker-Wonder-Quartz-Metallic/dp/B0C2K2WL6P
# 174. https://www.amazon.com/adidas-Falcon-Little-Sneaker-Yellow/dp/B0DK1B8HJR
# 175. https://www.amazon.com/adidas-Marvel-Falcon-Sneaker-Collegiate/dp/B0DJV7BHQ7
# 176. https://www.amazon.com/adidas-Elastic-Sneaker-Unisex-Toddler/dp/B0DJV87JZV
# 177. https://www.amazon.com/adidas-Originals-Sneaker-Running-Womens/dp/B00139YC2E
# 178. https://www.amazon.com/adidas-X_PLRPATH-Sneaker-Black-Unisex/dp/B0BZ5DB4Q5
# 179. https://www.amazon.com/adidas-Womens-Ultrarun-Sneaker-Metallic/dp/B0DHXCKJQG
# 180. https://www.amazon.com/adidas-Duramo-Elastic-Sneaker-Fusion/dp/B0BHPVMKPS
# 181. https://www.amazon.com/adidas-Racer-Sneaker-Unisex-Toddler/dp/B0CKM9HTTZ
# 182. https://www.amazon.com/adidas-Lightstride-Sportswear-Sneaker-Wonder/dp/B0D22W9CV3
# 183. https://www.amazon.com/adidas-Womens-Everyset-Training-Sneaker/dp/B0D2JDZCTN
# 184. https://www.amazon.com/adidas-Elastic-Sneaker-Silver-Metallic/dp/B0DJV2R1KK
# 185. https://www.amazon.com/adidas-Court-Sportswear-Sneaker-Shadow/dp/B0D2JDX5CT
# 186. https://www.amazon.com/adidas-Womens-CrazyChaos-Sneaker-Carbon/dp/B0CKMPH6MD
# 187. https://www.amazon.com/adidas-Sportswear-Sneaker-Better-Scarlet/dp/B0D2JKHB1N
# 188. https://www.amazon.com/adidas-Duramo-Sneaker-Unisex-Little/dp/B0BHPVC4XC
# 189. https://www.amazon.com/adidas-Trailmaker-Leather-Sneaker-Crimson/dp/B0D2JGTVT7
# 190. https://www.amazon.com/adidas-Ultrarun-Sneaker-White-Unisex/dp/B0D8X98N43
# 191. https://www.amazon.com/adidas-Fortarun-Elastic-Sportswear-Sneaker/dp/B0D22YKNGM
# 192. https://www.amazon.com/adidas-Womens-Break-Start-Sneaker/dp/B0DJV45Y38
# 193. https://www.amazon.com/adidas-Ultradream-Elastic-Sportswear-Sneaker/dp/B0D2JDPSR1
# 194. https://www.amazon.com/adidas-Marvel-Spider-Man-Falcon-Sneaker/dp/B0DJV3RGR8
# 195. https://www.amazon.com/adidas-Adizero-Instinct-Trainer-Sneaker/dp/B0CKMFK2LS
# 196. https://www.amazon.com/adidas-Womens-Sneaker-Impact-Orange/dp/B0DJVDCMHX
# url number: 196
# url ke-1 Gagal: https://www.amazon.com/adidas-Racer-Adapt-Sneaker-Black/dp/B0CKM9F15Z/ref=sr_1_1: HTTPSConnectionPool(host='api.scraperapi.com', port=443): Read timed out. (read timeout=15)
# url ke-2 Sukses: https://www.amazon.com/adidas-Falcon-Sneaker-Black-White/dp/B0CKMM7KSN/ref=sr_1_2
# url ke-3 Sukses: https://www.amazon.com/adidas-Mens-Swift-Sneaker-Black/dp/B0BHPV45TW/ref=sr_1_3
# url ke-4 Sukses: https://www.amazon.com/adidas-Mens-Ultraboost-Running-White/dp/B09VCNN65T/ref=sr_1_4
# url ke-5 Sukses: https://www.amazon.com/adidas-Womens-Falcon-Sneaker-Black/dp/B0CKMKV6H8/ref=sr_1_5
# url ke-6 Sukses: https://www.amazon.com/adidas-Mens-Kaptir-Sneaker-Black/dp/B0BG94ZLMP/ref=sr_1_6
# url ke-7 Sukses: https://www.amazon.com/adidas-Ultradream-Sportswear-Sneaker-Black/dp/B0D22WK79T/ref=sr_1_7
# url ke-8 Sukses: https://www.amazon.com/adidas-Duramo-Running-Sneaker-Silver/dp/B0D2JDHKDF/ref=sr_1_8
# url ke-9 Gagal: https://www.amazon.com/adidas-Questar-Sneaker-Preloved-Silver/dp/B0CKM8J4WX/ref=sr_1_9: HTTPSConnectionPool(host='api.scraperapi.com', port=443): Read timed out. (read timeout=15)
# url ke-10 Sukses: https://www.amazon.com/adidas-Racer-Footwear-White-Silver/dp/B0C6XPC39Q/ref=sr_1_10
# url ke-11 Sukses: https://www.amazon.com/adidas-Womens-Duramo-Running-Sneaker/dp/B0D2JBV2ZC/ref=sr_1_11
# url ke-12 Gagal: https://www.amazon.com/adidas-JH7253_580-Ultraboost-5X-Shoes/dp/B0DQ6D8XQM/ref=sr_1_12: HTTPSConnectionPool(host='api.scraperapi.com', port=443): Read timed out. (read timeout=15)
# url ke-13 Sukses: https://www.amazon.com/adidas-Mens-Racer-Running-Black/dp/B091MPYGKC/ref=sr_1_14
# url ke-14 Sukses: https://www.amazon.com/adidas-Mens-Falcon-White-Black/dp/B09Y7VQ32X/ref=sr_1_15
# url ke-15 Sukses: https://www.amazon.com/adidas-Kaptir-Sneaker-White-Black/dp/B0DJV8Q28D/ref=sr_1_16
# url ke-16 Sukses: https://www.amazon.com/adidas-Mens-X_PLR-Sneaker-Black/dp/B0CKMQBKW4/ref=sr_1_18
# url ke-17 Sukses: https://www.amazon.com/adidas-Lightstride-Sportswear-Sneaker-Scarlet/dp/B0D2JBP6JV/ref=sr_1_19
# url ke-18 Gagal: https://www.amazon.com/adidas-Supernova-Rise-Running-Shoes/dp/B0D8WSS4BX/ref=sr_1_20: HTTPSConnectionPool(host='api.scraperapi.com', port=443): Read timed out. (read timeout=15)
# url ke-19 Sukses: https://www.amazon.com/adidas-Response-Sneaker-Crystal-Metallic/dp/B0BXQ6DSK4/ref=sr_1_21
# url ke-20 Sukses: https://www.amazon.com/adidas-Womens-X_PLR-Sneaker-White/dp/B0CPS64W3Y/ref=sr_1_22
# url ke-21 Sukses: https://www.amazon.com/adidas-Mens-Sneaker-Dark-White/dp/B0CKMMB3QV/ref=sr_1_23
# url ke-22 Sukses: https://www.amazon.com/adidas-Sneaker-Black-White-Carbon/dp/B0CKMMR746/ref=sr_1_24
# url ke-23 Sukses: https://www.amazon.com/adidas-Lightshift-Sportswear-Sneaker-Black/dp/B0D22TQZ6Q/ref=sr_1_25
# url ke-24 Sukses: https://www.amazon.com/adidas-Womens-Sneaker-Purple-Scarlet/dp/B0DHZT6GT2/ref=sr_1_26
# url ke-25 Gagal: https://www.amazon.com/adidas-Womens-Sneaker-Silver-Metallic/dp/B0BHPST3LP/ref=sr_1_27: HTTPSConnectionPool(host='api.scraperapi.com', port=443): Read timed out. (read timeout=15)
# url ke-26 Sukses: https://www.amazon.com/adidas-Supernova-Running-Sneaker-White/dp/B0D2JF9S78/ref=sr_1_28
# url ke-27 Sukses: https://www.amazon.com/adidas-Duramo-Running-Sneaker-White/dp/B0DHXGXJ7H/ref=sr_1_29
# url ke-28 Sukses: https://www.amazon.com/adidas-Terrex-Tracefinder-Running-Sneaker/dp/B0D2JCZTS5/ref=sr_1_30
# url ke-29 Sukses: https://www.amazon.com/adidas-Kaptir-FTWWHT-CBLACK-Metallic/dp/B0CPSBYG79/ref=sr_1_31
# url ke-30 Sukses: https://www.amazon.com/adidas-Mens-Eclyptix-Sneaker-White/dp/B0D22WBCWP/ref=sr_1_32
# url ke-31 Sukses: https://www.amazon.com/adidas-Duramo-Sneaker-Black-Carbon/dp/B0BG6CPHZ8/ref=sr_1_33
# url ke-32 Sukses: https://www.amazon.com/adidas-Ultrabounce-Running-Sneaker-Black/dp/B0D2JGX4RF/ref=sr_1_34
# url ke-33 Sukses: https://www.amazon.com/adidas-Womens-Running-Sneaker-Metallic/dp/B0D33R68XR/ref=sr_1_35
# url ke-34 Sukses: https://www.amazon.com/adidas-Womens-Puremotion-Sportswear-Sneaker/dp/B0BHPSG7XM/ref=sr_1_37
# url ke-35 Sukses: https://www.amazon.com/Adidas-Supernova-Prima-Running-Shoes/dp/B0DKVM27FK/ref=sr_1_38
# url ke-36 Sukses: https://www.amazon.com/adidas-Astrastar-Sneaker-Black-White/dp/B0DJV5WQVR/ref=sr_1_39
# url ke-37 Sukses: https://www.amazon.com/adidas-Duramo-Sneaker-Metallic-Aurora/dp/B0BXQ661QF/ref=sr_1_40
# url ke-38 Sukses: https://www.amazon.com/adidas-Unisex-Ultraboost-Running-Crystal/dp/B09VCLVMFH/ref=sr_1_41
# url ke-39 Sukses: https://www.amazon.com/adidas-Falcon-Running-Sneaker-Metallic/dp/B0D32XWJ4K/ref=sr_1_42
# url ke-40 Sukses: https://www.amazon.com/adidas-Ultrabounce-Sneaker-White-Silver/dp/B0CKMBSBG3/ref=sr_1_43
# url ke-41 Sukses: https://www.amazon.com/adidas-Womens-Vario-Black-White/dp/B08CZDDWX9/ref=sr_1_44
# url ke-42 Sukses: https://www.amazon.com/adidas-Womens-Swift-Sneaker-Preloved/dp/B0DJV7K2JJ/ref=sr_1_45
# url ke-43 Sukses: https://www.amazon.com/adidas-Originals-Womens-Swift-Sneaker/dp/B091V6SM5Z/ref=sr_1_47
# url ke-44 Sukses: https://www.amazon.com/adidas-Womens-Sneaker-Blanch-Wonder/dp/B0DLTD1GBV/ref=sr_1_48
# url ke-45 Sukses: https://www.amazon.com/Under-Armour-Charged-Assert-Running/dp/B09XBVM335/ref=sr_1_49
# url ke-46 Sukses: https://www.amazon.com/adidas-Ultraboost-Running-Black-White/dp/B091MQ45J3/ref=sr_1_50
# url ke-47 Sukses: https://www.amazon.com/adidas-X_PLR-Sneaker-Black-White/dp/B0DJV5N49V/ref=sr_1_51
# url ke-48 Sukses: https://www.amazon.com/adidas-Womens-Pureboost-Sneaker-Metallic/dp/B0CKMC9SLT/ref=sr_1_54
# url ke-49 Sukses: https://www.amazon.com/adidas-Womens-Supernova-Stride-Sneaker/dp/B0BXQ4RWYD/ref=sr_1_55
# url ke-50 Sukses: https://www.amazon.com/adidas-Womens-Ultradream-Sportswear-Sneaker/dp/B0D2JG29RH/ref=sr_1_56
# url ke-51 Sukses: https://www.amazon.com/adidas-Womens-Cloudfoam-Sportswear-Sneakers/dp/B0BZ5NB719/ref=sr_1_58
# url ke-52 Sukses: https://www.amazon.com/adidas-Mens-Racer-Sneaker-White/dp/B0BHPTW5WL/ref=sr_1_59
# url ke-53 Sukses: https://www.amazon.com/adidas-Pureboost-Sneaker-Silver-Metallic/dp/B0CKM95RJC/ref=sr_1_60
# url ke-54 Sukses: https://www.amazon.com/adidas-Womens-SoulStride-Sneaker-Crystal/dp/B0BG3D2XZM/ref=sr_1_61
# url ke-55 Sukses: https://www.amazon.com/adidas-Supernova-Running-Sneaker-Metallic/dp/B0D2Z2HBK2/ref=sr_1_62
# url ke-56 Sukses: https://www.amazon.com/adidas-FTWWHT-PURTEA-Adizero-whitePure/dp/B0DVQ2ZSBJ/ref=sr_1_63
# url ke-57 Sukses: https://www.amazon.com/adidas-Womens-Ultraboost-Sneaker-White/dp/B0CPS85BCS/ref=sr_1_64
# url ke-58 Sukses: https://www.amazon.com/adidas-Falcon-Sneaker-Silver-Metallic/dp/B0CKMCS5CJ/ref=sr_1_65
# url ke-59 Sukses: https://www.amazon.com/adidas-Adizero-Boston-Sneaker-Metallic/dp/B0CSM3JRQH/ref=sr_1_66
# url ke-60 Sukses: https://www.amazon.com/adidas-Ultraboost-Light-Running-Shoes/dp/B0BRNQWSM9/ref=sr_1_67
# url ke-61 Sukses: https://www.amazon.com/adidas-Mens-Sneaker-Grey-Shadow/dp/B0BHPQX6TQ/ref=sr_1_69
# url ke-62 Sukses: https://www.amazon.com/adidas-Supernova-Running-Sneaker-Bright/dp/B0D33RT5X2/ref=sr_1_70
# url ke-63 Sukses: https://www.amazon.com/adidas-Response-Super-Sneaker-Silver/dp/B0C2JVDRHQ/ref=sr_1_71
# url ke-64 Sukses: https://www.amazon.com/adidas-Kaptir-Womens-Running-Shoes/dp/B0CPSBPBN3/ref=sr_1_72
# url ke-65 Sukses: https://www.amazon.com/adidas-Womens-Response-Sneaker-Purple/dp/B0CM84CJKZ/ref=sr_1_73
# url ke-66 Sukses: https://www.amazon.com/adidas-Womens-X_PLRPHASE-Sneaker-Preloved/dp/B0CMRXSFNX/ref=sr_1_74
# url ke-67 Sukses: https://www.amazon.com/adidas-Sneaker-Yellow-Black-White/dp/B0DHZVLKJ2/ref=sr_1_76
# url ke-68 Sukses: https://www.amazon.com/adidas-Ultraboost-Running-Sneaker-White/dp/B0D3P22L2W/ref=sr_1_77
# url ke-69 Gagal: https://www.amazon.com/adidas-Womens-RunBlaze-Sneaker-Bliss/dp/B0DLBSZK38/ref=sr_1_78: HTTPSConnectionPool(host='api.scraperapi.com', port=443): Read timed out. (read timeout=15)
# url ke-70 Sukses: https://www.amazon.com/adidas-Terrex-Anylander-Sneaker-Strata/dp/B0CKM7S36V/ref=sr_1_79
# url ke-71 Sukses: https://www.amazon.com/adidas-Ultraboost-Sneaker-White-Glory/dp/B0CKM6KYWJ/ref=sr_1_80
# url ke-72 Sukses: https://www.amazon.com/adidas-Sneaker-Purple-Better-Scarlet/dp/B0DJV6W2P6/ref=sr_1_81
# url ke-73 Gagal: https://www.amazon.com/adidas-Flowboost-Sportswear-Sneaker-Collegiate/dp/B0D2JDF3BR/ref=sr_1_83: HTTPSConnectionPool(host='api.scraperapi.com', port=443): Read timed out. (read timeout=15)
# url ke-74 Sukses: https://www.amazon.com/adidas-Running-Sneaker-Wonder-Alumina/dp/B0D2JF99JK/ref=sr_1_85
# url ke-75 Sukses: https://www.amazon.com/adidas-Originals-Swift-Sneaker-Black/dp/B098999VT2/ref=sr_1_86
# url ke-76 Gagal: https://www.amazon.com/adidas-Swift-Womens-F35206-Size/dp/B07TXRCKRD/ref=sr_1_87: HTTPSConnectionPool(host='api.scraperapi.com', port=443): Read timed out. (read timeout=15)
# url ke-77 Sukses: https://www.amazon.com/adidas-Sportswear-Sneaker-Court-Carbon/dp/B0D2JDMTT3/ref=sr_1_88
# url ke-78 Sukses: https://www.amazon.com/adidas-Lightstride-Sportswear-Sneaker-Crystal/dp/B0D2JCVGJB/ref=sr_1_90
# url ke-79 Sukses: https://www.amazon.com/adidas-Adistar-Sneaker-White-Black/dp/B0CM81J2BD/ref=sr_1_91
# url ke-80 Sukses: https://www.amazon.com/adidas-X_PLR-Sneaker-White-Unisex/dp/B0CRDF7YPV/ref=sr_1_92
# url ke-81 Gagal: https://www.amazon.com/adidas-Barreda-Decode-Sneaker-Impact/dp/B0DJV4N6HX/ref=sr_1_93: HTTPSConnectionPool(host='api.scraperapi.com', port=443): Read timed out. (read timeout=15)
# url ke-82 Sukses: https://www.amazon.com/adidas-Swift-Sneaker-Black-White/dp/B0BHPSFLNT/ref=sr_1_94
# url ke-83 Sukses: https://www.amazon.com/adidas-Ultraboost-Running-Legacy-Indigo/dp/B091M9K65B/ref=sr_1_95
# url ke-84 Sukses: https://www.amazon.com/adidas-Terrex-Agravic-Running-Sneaker/dp/B0D2PHFZYZ/ref=sr_1_96
# url ke-85 Sukses: https://www.amazon.com/Adidas-JH7248-Ultraboost-5X-Shoes/dp/B0DKVBFCYF/ref=sr_1_98
# url ke-86 Gagal: https://www.amazon.com/adidas-Supernova-Stride-Sneaker-Metallic/dp/B0CM7Q2GG8/ref=sr_1_100: HTTPSConnectionPool(host='api.scraperapi.com', port=443): Read timed out. (read timeout=15)
# url ke-87 Gagal: https://www.amazon.com/adidas-Womens-Questar-Sneaker-Silver/dp/B0CKM9J7P2/ref=sr_1_101: HTTPSConnectionPool(host='api.scraperapi.com', port=443): Read timed out. (read timeout=15)
# url ke-88 Sukses: https://www.amazon.com/adidas-Samba-Classic-Shoes-Mens/dp/B000CER6SS/ref=sr_1_102
# url ke-89 Gagal: https://www.amazon.com/adidas-Womens-Breaknet-Sneaker-Alumina/dp/B0DJV9NNZY/ref=sr_1_103: HTTPSConnectionPool(host='api.scraperapi.com', port=443): Read timed out. (read timeout=15)
# url ke-90 Sukses: https://www.amazon.com/adidas-Womens-Response-Running-Sneaker/dp/B0D2JGX8GR/ref=sr_1_104
# url ke-91 Sukses: https://www.amazon.com/adidas-Womens-Sportswear-Sneaker-Alumina/dp/B0D2JF8D2N/ref=sr_1_106
# url ke-92 Sukses: https://www.amazon.com/adidas-Terrex-Soulstride-Sneaker-Crystal/dp/B0C2JY7TK9/ref=sr_1_107
# url ke-93 Sukses: https://www.amazon.com/adidas-Falcon-Sneaker-Black-Unisex/dp/B0CKMCK1VH/ref=sr_1_108
# url ke-94 Sukses: https://www.amazon.com/adidas-UBounce-Sneaker-White-Black/dp/B0CCQ1MBPN/ref=sr_1_109
# url ke-95 Sukses: https://www.amazon.com/adidas-Womens-Ultraboost-Running-Crystal/dp/B09VCKXRWG/ref=sr_1_110
# url ke-96 Sukses: https://www.amazon.com/adidas-Duramo-Sneaker-Carbon-Unisex/dp/B0BHPWG6XD/ref=sr_1_114
# url ke-97 Sukses: https://www.amazon.com/adidas-Pureboost-Running-Solar-Yellow/dp/B09KMJ3MNJ/ref=sr_1_116
# url ke-98 Gagal: https://www.amazon.com/adidas-Barreda-Sneaker-Earth-Strata/dp/B0DLBRVVPB/ref=sr_1_118: HTTPSConnectionPool(host='api.scraperapi.com', port=443): Read timed out. (read timeout=15)
# url ke-99 Sukses: https://www.amazon.com/ALEADER-Energycloud-Walking-Running-Treadmill/dp/B09PNFMMXP/ref=sr_1_119
# url ke-100 Sukses: https://www.amazon.com/adidas-Womens-Ultraboost-Running-Collegiate/dp/B091MCKN74/ref=sr_1_120
# url ke-101 Sukses: https://www.amazon.com/adidas-X_PLRPATH-Sneaker-Black-Cross/dp/B0BZ5TNVKF/ref=sr_1_122
# url ke-102 Sukses: https://www.amazon.com/Under-Armour-Charged-Assert-Black/dp/B087TH4JM6/ref=sr_1_123
# url ke-103 Sukses: https://www.amazon.com/adidas-Lightstride-Sneaker-Collegiate-Silver/dp/B0D22YD984/ref=sr_1_124
# url ke-104 Sukses: https://www.amazon.com/adidas-Womens-Running-White-Purple/dp/B08N5FPSWV/ref=sr_1_125
# url ke-105 Sukses: https://www.amazon.com/adidas-Womens-Running-Carbon-Metallic/dp/B08MY72SKK/ref=sr_1_127
# url ke-106 Sukses: https://www.amazon.com/adidas-Mens-Running-Black-White/dp/B09DZW747P/ref=sr_1_128
# url ke-107 Sukses: https://www.amazon.com/adidas-womens-Racer-Grey-White/dp/B087KVQYXJ/ref=sr_1_129
# url ke-108 Sukses: https://www.amazon.com/adidas-Falcon-Black-Unisex-Little/dp/B09VCT6HX2/ref=sr_1_130
# url ke-109 Sukses: https://www.amazon.com/adidas-Womens-Ultrabounce-Sneaker-Black/dp/B0CKMK6Y1N/ref=sr_1_131
# url ke-110 Sukses: https://www.amazon.com/adidas-Sneaker-Strata-Silver-Pebble/dp/B0CM7VT9KN/ref=sr_1_132
# url ke-111 Sukses: https://www.amazon.com/adidas-Response-Running-Sneaker-Carbon/dp/B0D2JGJ799/ref=sr_1_133
# url ke-112 Sukses: https://www.amazon.com/adidas-Womens-Tracefinder-Running-Sneaker/dp/B0D2JKD1T3/ref=sr_1_134
# url ke-113 Sukses: https://www.amazon.com/adidas-Supernova-Running-Sneaker-Crystal/dp/B0D2Z7XP7Q/ref=sr_1_135
# url ke-114 Sukses: https://www.amazon.com/adidas-White-Tint-Silver-Metallic/dp/B0BJW3LTGJ/ref=sr_1_136
# url ke-115 Sukses: https://www.amazon.com/adidas-Womens-Ultrarun-Running-Sneaker/dp/B0D2JBCQ3G/ref=sr_1_137
# url ke-116 Sukses: https://www.amazon.com/adidas-X_PLRBOOST-Running-Black-White/dp/B0B5YNNWSK/ref=sr_1_138
# url ke-117 Sukses: https://www.amazon.com/adidas-Unisex-Ultraboost-Sneaker-White/dp/B0CM847GBR/ref=sr_1_139
# url ke-118 Sukses: https://www.amazon.com/adidas-Mens-2000-Runner-Sneaker/dp/B0CKMHY6Y6/ref=sr_1_140
# url ke-119 Sukses: https://www.amazon.com/adidas-Terrex-Soulstride-Crystal-Wonder/dp/B0CC22QCCG/ref=sr_1_141
# url ke-120 Sukses: https://www.amazon.com/adidas-Tracefinder-Climaproof-Running-Preloved/dp/B0DHW1F1J7/ref=sr_1_142
# url ke-121 Sukses: https://www.amazon.com/adidas-Adizero-Mens-Running-Shoes/dp/B0CKM1KCWZ/ref=sr_1_143
# url ke-122 Sukses: https://www.amazon.com/adidas-Unisex-Pureboost-Running-Shadow/dp/B09KP61496/ref=sr_1_144
# url ke-123 Sukses: https://www.amazon.com/adidas-Ultrarun-Running-Sneaker-Preloved/dp/B0D2JJH6N4/ref=sr_1_145
# url ke-124 Sukses: https://www.amazon.com/adidas-Astrastar-Sneaker-Alumina-Metallic/dp/B0DJV35KT4/ref=sr_1_146
# url ke-125 Sukses: https://www.amazon.com/adidas-Fortarun-Sportswear-Sneaker-Unisex/dp/B0D2JJL6QB/ref=sr_1_148
# url ke-126 Sukses: https://www.amazon.com/adidas-Supernova-Running-Sneaker-Unisex/dp/B0D2JJW79Q/ref=sr_1_149
# url ke-127 Sukses: https://www.amazon.com/adidas-Response-Shoes-Mens-White/dp/B0CB9F5NZV/ref=sr_1_150
# url ke-128 Sukses: https://www.amazon.com/adidas-Mens-Runfalcon-Black-White/dp/B087M2KPR2/ref=sr_1_151
# url ke-129 Sukses: https://www.amazon.com/adidas-Kaptir-Sneaker-Blanch-Alumina/dp/B0CKMMN1BT/ref=sr_1_153
# url ke-130 Sukses: https://www.amazon.com/adidas-Duramo-Trail-Running-Royal/dp/B08N5JDB2V/ref=sr_1_154
# url ke-131 Sukses: https://www.amazon.com/adidas-Alphaboost-Sneaker-White-Solid/dp/B0CKMC3TYC/ref=sr_1_155
# url ke-132 Sukses: https://www.amazon.com/adidas-Elastic-Sportswear-Sneaker-Unisex/dp/B0D22W71HC/ref=sr_1_156
# url ke-133 Sukses: https://www.amazon.com/adidas-Duramo-Running-Sneakers-Shoes/dp/B0D31V48XG/ref=sr_1_157
# url ke-134 Sukses: https://www.amazon.com/adidas-AlphaBoost-Running-Black-Magic/dp/B09VCL828H/ref=sr_1_158
# url ke-135 Sukses: https://www.amazon.com/adidas-Originals-Sneaker-Running-Medium/dp/B00139U3DQ/ref=sr_1_161
# url ke-136 Sukses: https://www.amazon.com/adidas-Falcon-Running-Sneaker-Black/dp/B0D2JF57GN/ref=sr_1_162
# url ke-137 Sukses: https://www.amazon.com/adidas-Unisex-Avery-Running-Carbon/dp/B09VCLWLZZ/ref=sr_1_163
# url ke-138 Sukses: https://www.amazon.com/adidas-Terrex-SoulStride-Sneaker-Carbon/dp/B0BHPTYQGP/ref=sr_1_164
# url ke-139 Sukses: https://www.amazon.com/adidas-Ultrabounce-Mens-Shoes-Color/dp/B0CC6J634K/ref=sr_1_165
# url ke-140 Sukses: https://www.amazon.com/adidas-Womens-Kantai-Sportswear-Sneaker/dp/B0D2JFF32Q/ref=sr_1_168
# url ke-141 Sukses: https://www.amazon.com/adidas-Amplimove-Training-Sneaker-Lucid/dp/B0D2JFPH31/ref=sr_1_170
# url ke-142 Sukses: https://www.amazon.com/adidas-Alphaboost-Sneaker-Collegiate-University/dp/B0DF12DR57/ref=sr_1_171
# url ke-143 Sukses: https://www.amazon.com/adidas-Unisex-Turnaround-Sneaker-Crystal/dp/B0CMGPZRC5/ref=sr_1_172
# url ke-144 Sukses: https://www.amazon.com/adidas-Lightblaze-Sneaker-Silver-Metallic/dp/B0DJTYKXNZ/ref=sr_1_173
# url ke-145 Sukses: https://www.amazon.com/adidas-Kantai-Sportswear-Sneaker-Charcoal/dp/B0D22WSCYZ/ref=sr_1_174
# url ke-146 Sukses: https://www.amazon.com/adidas-Duramo-Sneaker-Fusion-Unisex/dp/B0BHPV8H17/ref=sr_1_177
# url ke-147 Sukses: https://www.amazon.com/adidas-Ultradream-Sneaker-White-Unisex/dp/B0DNGJKXCY/ref=sr_1_178
# url ke-148 Sukses: https://www.amazon.com/adidas-Ultrabounce-Sneaker-Black-Unisex/dp/B0CKMC9C19/ref=sr_1_180
# url ke-149 Sukses: https://www.amazon.com/adidas-Runner-Sneaker-Blanch-Cargo/dp/B0CKMKNRXB/ref=sr_1_182
# url ke-150 Gagal: https://www.amazon.com/adidas-Ultrarun-Sneaker-Unisex-Little/dp/B0DLCFVZQZ/ref=sr_1_183: HTTPSConnectionPool(host='api.scraperapi.com', port=443): Read timed out. (read timeout=15)
# url ke-151 Sukses: https://www.amazon.com/adidas-Womens-Lightshift-Sportswear-Sneaker/dp/B0D22W7Y3L/ref=sr_1_184
# url ke-152 Sukses: https://www.amazon.com/adidas-Sportswear-Sneaker-Wonder-Quartz/dp/B0D28TJSHP/ref=sr_1_185
# url ke-153 Sukses: https://www.amazon.com/adidas-Unisex-VULCRAID3R-Running-White/dp/B09KMJX6Z7/ref=sr_1_186
# url ke-154 Sukses: https://www.amazon.com/adidas-Mould-Bungee-Sneaker-Collegiate/dp/B0CKMK4ZRQ/ref=sr_1_187
# url ke-155 Sukses: https://www.amazon.com/adidas-Mens-Barreda-Decode-Sneaker/dp/B0DJTXZKKM/ref=sr_1_188
# url ke-156 Sukses: https://www.amazon.com/adidas-Falcon-Sneaker-Unisex-Little/dp/B0DLCN1ZHK/ref=sr_1_189
# url ke-157 Sukses: https://www.amazon.com/adidas-Womens-Ubounce-Alphaskin-Sneaker/dp/B0BZ5B116M/ref=sr_1_190
# url ke-158 Sukses: https://www.amazon.com/adidas-Elastic-Sneaker-Scarlet-Metallic/dp/B0DHZJT9Z3/ref=sr_1_191
# url ke-159 Sukses: https://www.amazon.com/adidas-Elastic-Sneaker-Better-Scarlet/dp/B0CRH8X6LT/ref=sr_1_192
# url ke-160 Sukses: https://www.amazon.com/adidas-Womens-Duramo-Sneaker-Carbon/dp/B0BG6B24Q8
# url ke-161 Sukses: https://www.amazon.com/adidas-Lightshift-Sportswear-Sneaker-Lavender/dp/B0D22QZ2DX
# url ke-162 Sukses: https://www.amazon.com/adidas-Supernova-Stride-Sneaker-Scarlet/dp/B0C2JTDRD4
# url ke-163 Sukses: https://www.amazon.com/adidas-Grand-Sportswear-Sneaker-Metallic/dp/B0D22WQPT3
# url ke-164 Sukses: https://www.amazon.com/adidas-Cloudfoam-Sportswear-Sneaker-Preloved/dp/B0D2JD494C
# url ke-165 Sukses: https://www.amazon.com/adidas-unisex-kids-Kaptir-3-0-Black/dp/B0BTZB64X2
# url ke-166 Sukses: https://www.amazon.com/adidas-Kaptir-Sneaker-Aurora-Metallic/dp/B0DJV7L7RF
# url ke-167 Sukses: https://www.amazon.com/adidas-Duramo-Elastic-Sneaker-Bright/dp/B0DJV9SQP9
# url ke-168 Sukses: https://www.amazon.com/adidas-Duramo-Elastic-Sportswear-Sneaker/dp/B0D22TBK34
# url ke-169 Sukses: https://www.amazon.com/adidas-Ultrarun-Elastic-Sneaker-Unisex/dp/B0DHZF2JW9
# url ke-170 Sukses: https://www.amazon.com/adidas-Womens-Supernova-Sneaker-Bright/dp/B0BHPT278K
# url ke-171 Sukses: https://www.amazon.com/adidas-Womens-Breaknet-Sneaker-Shadow/dp/B0CKMP3YLJ
# url ke-172 Sukses: https://www.amazon.com/adidas-Ultrabounce-Elastic-Sneaker-Unisex/dp/B0CKMBZHYY
# url ke-173 Sukses: https://www.amazon.com/adidas-Sneaker-Wonder-Quartz-Metallic/dp/B0C2K2WL6P
# url ke-174 Sukses: https://www.amazon.com/adidas-Falcon-Little-Sneaker-Yellow/dp/B0DK1B8HJR
# url ke-175 Sukses: https://www.amazon.com/adidas-Marvel-Falcon-Sneaker-Collegiate/dp/B0DJV7BHQ7
# url ke-176 Sukses: https://www.amazon.com/adidas-Elastic-Sneaker-Unisex-Toddler/dp/B0DJV87JZV
# url ke-177 Sukses: https://www.amazon.com/adidas-Originals-Sneaker-Running-Womens/dp/B00139YC2E
# url ke-178 Sukses: https://www.amazon.com/adidas-X_PLRPATH-Sneaker-Black-Unisex/dp/B0BZ5DB4Q5
# url ke-179 Sukses: https://www.amazon.com/adidas-Womens-Ultrarun-Sneaker-Metallic/dp/B0DHXCKJQG
# url ke-180 Sukses: https://www.amazon.com/adidas-Duramo-Elastic-Sneaker-Fusion/dp/B0BHPVMKPS
# url ke-181 Sukses: https://www.amazon.com/adidas-Racer-Sneaker-Unisex-Toddler/dp/B0CKM9HTTZ
# url ke-182 Sukses: https://www.amazon.com/adidas-Lightstride-Sportswear-Sneaker-Wonder/dp/B0D22W9CV3
# url ke-183 Sukses: https://www.amazon.com/adidas-Womens-Everyset-Training-Sneaker/dp/B0D2JDZCTN
# url ke-184 Sukses: https://www.amazon.com/adidas-Elastic-Sneaker-Silver-Metallic/dp/B0DJV2R1KK
# url ke-185 Sukses: https://www.amazon.com/adidas-Court-Sportswear-Sneaker-Shadow/dp/B0D2JDX5CT
# url ke-186 Sukses: https://www.amazon.com/adidas-Womens-CrazyChaos-Sneaker-Carbon/dp/B0CKMPH6MD
# url ke-187 Sukses: https://www.amazon.com/adidas-Sportswear-Sneaker-Better-Scarlet/dp/B0D2JKHB1N
# url ke-188 Sukses: https://www.amazon.com/adidas-Duramo-Sneaker-Unisex-Little/dp/B0BHPVC4XC
# url ke-189 Sukses: https://www.amazon.com/adidas-Trailmaker-Leather-Sneaker-Crimson/dp/B0D2JGTVT7
# url ke-190 Sukses: https://www.amazon.com/adidas-Ultrarun-Sneaker-White-Unisex/dp/B0D8X98N43
# url ke-191 Sukses: https://www.amazon.com/adidas-Fortarun-Elastic-Sportswear-Sneaker/dp/B0D22YKNGM
# url ke-192 Sukses: https://www.amazon.com/adidas-Womens-Break-Start-Sneaker/dp/B0DJV45Y38
# url ke-193 Sukses: https://www.amazon.com/adidas-Ultradream-Elastic-Sportswear-Sneaker/dp/B0D2JDPSR1
# url ke-194 Sukses: https://www.amazon.com/adidas-Marvel-Spider-Man-Falcon-Sneaker/dp/B0DJV3RGR8
# url ke-195 Sukses: https://www.amazon.com/adidas-Adizero-Instinct-Trainer-Sneaker/dp/B0CKMFK2LS
# url ke-196 Sukses: https://www.amazon.com/adidas-Womens-Sneaker-Impact-Orange/dp/B0DJVDCMHX

# %%
len(review_data)
# Out:
# 163

# %%
# Menyimpan data dalam format JSON
with open("adidas.json", "w", encoding="utf-8") as review_json:
    json.dump(review_data, review_json, indent=2, ensure_ascii=True)
